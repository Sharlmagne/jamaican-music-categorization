# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats import weightstats, oneway
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('Files/tracks_final.csv')

# %%
df.head()
# Out:
#   Artist Name  Track Name  Popularity Explicit  Danceability  Energy    Key  Loudness  Speechiness  Acousticness  Liveness  Valence  Tempo   Mode  Release Year  Duration   Clusters
# 0      $wizzz     L.I.F.E          13    Clean         0.618   0.557      C  0.860805       0.0747      0.482000     0.294    0.332  144.0  Major          2021  2.703233  Cluster 4
# 1      $wizzz      G-spot          10    Clean         0.711   0.444      G  0.799437       0.2800      0.543000     0.118    0.630   80.0  Minor          2021  3.622750  Cluster 2
# 2      $wizzz  High grade          10    Clean         0.516   0.684  C#/Db  0.847653       0.0467      0.139000     0.113    0.135  100.0  Minor          2021  3.716350  Cluster 4
# 3      $wizzz       Story          10    Clean         0.491   0.467      C  0.749076       0.0545      0.154000     0.146    0.574  132.0  Minor          2021  3.245300  Cluster 4
# 4      $wizzz      Bubble          12    Clean         0.590   0.592      F  0.791504       0.2340      0.000575     0.405    0.293   70.0  Minor          2021  3.257150  Cluster 4

# %%
# Create separate dataframe for each cluster
cluster1 = df[df["Clusters"] == "Cluster 1"]
cluster2 = df[df["Clusters"] == "Cluster 2"]
cluster3 = df[df["Clusters"] == "Cluster 3"]
cluster4 = df[df["Clusters"] == "Cluster 4"]

# %% [markdown]
# ### Funtions

# %%
# Reveil the central tendencies of the data with info

def describe(df, feature):
    """
    Expects: Dataframe with all artists and the specific feature to describe
    Return: Dataframe with metrics on central tendencies
    """
    for i in range(1,5):
        cluster_name = f"Cluster {i}"
        cluster = df[df["Clusters"] == cluster_name][feature]
        
        # Calculate IQR
        q1 = cluster.quantile(0.25)
        q3 = cluster.quantile(0.75)
        iqr = q3 - q1
        df_describe = df[df["Clusters"] == cluster_name][[feature]].describe()
        df_describe = pd.pivot_table(df_describe, columns = list(df_describe.index)) 
        display(df_describe)
        print(f"The interquartile range (IQR) for {cluster_name} is {iqr}")
        
        # Variance
        variance = df[df["Clusters"] == cluster_name][feature].var()
        print(f"Variance is equal to {variance}")
        
        #Outliers
        out1 = q1 - iqr*1.5
        out3 = q3 + iqr*1.5
        outlier_sum = cluster[cluster < out1].count() + cluster[cluster > out3].count()
        outlier_percentage = round(((outlier_sum/cluster.count())*100),2)
        print(f"total number of outliers are {outlier_sum} which is {outlier_percentage}% of the cluster")
        print("")
        print("")

# %%
# Reveil the central tendencies of the data with plots.

def plot(df, feature):
    """
    Expects: Dataframe with all artists and the specific feature to describe
    Return: Histgram and box plots
    """
    order = ["Cluster 1","Cluster 2","Cluster 3","Cluster 4"]
    sns.displot(df, x=feature, hue="Clusters", kde=True, hue_order=order, multiple="stack", 
                # height=8.27, aspect=(11.7/8.27)
               );
    sns.catplot(data=df, y=feature, x="Clusters", order=order, kind="box");

# %%
#Run anova and ad-hoc test to determine the difference in feature between clusters
def anova(feature, sample_size):
    """
    Expects: Feature to describe and sample size
    Return: Result for anova test comparing all the clusters and the Tuckey's HSD to confirm similarities/dissimilarities
    """
    c1 = cluster1[feature].sample(n=sample_size).tolist()
    c2 = cluster2[feature].sample(n=sample_size).tolist()
    c3 = cluster3[feature].sample(n=sample_size).tolist()
    c4 = cluster4[feature].sample(n=sample_size).tolist()

    df = pd.concat([
        pd.DataFrame(data={feature:c1, "Cluster":"Cluster 1"}),
        pd.DataFrame(data={feature:c2, "Cluster":"Cluster 2"}),
        pd.DataFrame(data={feature:c3, "Cluster":"Cluster 3"}),
        pd.DataFrame(data={feature:c4, "Cluster":"Cluster 4"})
    ])

    print(stats.f_oneway(c1, c2, c3, c4))
    print("______________________________________________________________")
    print(oneway.anova_oneway((c1, c2, c3, c4)))
    print("______________________________________________________________")
    results = pairwise_tukeyhsd(endog=df[feature], groups=df["Cluster"], alpha=0.05)
    print(results)

# %%
# Compare the differences in features among clusters
def ratings(feature, sample_size):
    """
    Expects: Feature to describe and sample size
    Return: Bar graphs showing the features per cluster
    """
    c1 = cluster1[feature].sample(n=sample_size).mean()
    c2 = cluster2[feature].sample(n=sample_size).mean()
    c3 = cluster3[feature].sample(n=sample_size).mean()
    c4 = cluster4[feature].sample(n=sample_size).mean()
    
    ratings = {"means":[c1,c2,c3,c4],
           "clusters":["Cluster 1", "Cluster 2", "Cluster 3", "Cluster 4"]
          }
    df = pd.DataFrame(ratings)
    
    sns.barplot(data=df, y="clusters" , x="means");

# %%
# Side by display of clusters and all their features
def compare(df, sample_size):
    """
    Expects: Parent dataframe and sample size
    Return: Bar graphs showing the all features for all the clusters
    """
    features = df.columns[4:12].tolist()
    features.pop(2)
    c1 = cluster1[features].sample(sample_size).mean()
    c2 = cluster2[features].sample(sample_size).mean()
    c3 = cluster3[features].sample(sample_size).mean()
    c4 = cluster4[features].sample(sample_size).mean()
    
    compare = pd.concat([
        pd.DataFrame(c1, columns=["Cluster 1"]),
        pd.DataFrame(c2, columns=["Cluster 2"]),
        pd.DataFrame(c3, columns=["Cluster 3"]),
        pd.DataFrame(c4, columns=["Cluster 4"])
    ], axis=1)
    
    fig, axs = plt.subplots(ncols=4, figsize=(30,8))
    plt.setp(axs, xlim=(0, 0.9))
    sns.barplot(data=compare[["Cluster 1"]], x="Cluster 1", y=compare.index, ax=axs[0]);
    sns.barplot(data=compare[["Cluster 2"]], x="Cluster 2", y=compare.index, ax=axs[1]);
    sns.barplot(data=compare[["Cluster 3"]], x="Cluster 3", y=compare.index, ax=axs[2]);
    sns.barplot(data=compare[["Cluster 4"]], x="Cluster 4", y=compare.index, ax=axs[3]);
    # axs.grid(axis="x")

# %% [markdown]
# ### Popularity

# %%
plot(df, "Danceability")

# %%
describe(df, "Popularity")
# Out:
#             25%  50%  75%   count   max      mean  min       std
# Popularity  0.0  2.0  8.0  6847.0  62.0  6.229151  0.0  9.245487
# The interquartile range (IQR) for Cluster 1 is 8.0
# Variance is equal to 85.47903321208635
# total number of outliers are 586 which is 8.56% of the cluster
#             25%  50%   75%   count   max      mean  min        std
# Popularity  0.0  3.0  11.0  3081.0  62.0  7.692632  0.0  10.389991
# The interquartile range (IQR) for Cluster 2 is 11.0
# Variance is equal to 107.95192297154323
# total number of outliers are 204 which is 6.62% of the cluster
#             25%  50%   75%   count   max      mean  min        std
# Popularity  1.0  5.0  15.0  9691.0  75.0  9.815499  0.0  12.195349
# The interquartile range (IQR) for Cluster 3 is 14.0
# Variance is equal to 148.7265337526046
# total number of outliers are 475 which is 4.9% of the cluster
#             25%  50%   75%   count   max       mean  min        std
# Popularity  1.0  7.0  17.0  6757.0  69.0  11.031819  0.0  12.228533
# The interquartile range (IQR) for Cluster 4 is 16.0
# Variance is equal to 149.5370276711483
# total number of outliers are 183 which is 2.71% of the cluster

# %% [markdown]
# Popularity: popularity in the most part, is based on the total number of plays the track has had and how recent those plays are. Songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past.

# %%
cluster1[cluster1["Popularity"] > 30]["Popularity"].count()
# Out:
# 228

# %%
cluster2[cluster2["Popularity"] > 30]["Popularity"].count()
# Out:
# 148

# %%
cluster3[cluster3["Popularity"] > 30]["Popularity"].count()
# Out:
# 808

# %%
cluster4[cluster4["Popularity"] > 30]["Popularity"].count()
# Out:
# 633

# %% [markdown]
# ### Danceability

# %%
plot(df, "Danceability")

# %%
describe(df, "Danceability")
# Out:
#                  25%    50%    75%   count    max      mean   min      std
# Danceability  0.7225  0.779  0.833  6847.0  0.983  0.772987  0.29  0.08502
# The interquartile range (IQR) for Cluster 1 is 0.11050000000000004
# Variance is equal to 0.007228470482006851
# total number of outliers are 96 which is 1.4% of the cluster
#                 25%    50%    75%   count    max      mean    min       std
# Danceability  0.581  0.677  0.758  3081.0  0.956  0.661866  0.148  0.136158
# The interquartile range (IQR) for Cluster 2 is 0.17700000000000005
# Variance is equal to 0.018539008561691474
# total number of outliers are 45 which is 1.46% of the cluster
#                 25%    50%    75%   count   max      mean    min       std
# Danceability  0.715  0.772  0.829  9691.0  0.99  0.770616  0.444  0.081752
# The interquartile range (IQR) for Cluster 3 is 0.11399999999999999
# Variance is equal to 0.006683463852612282
# total number of outliers are 40 which is 0.41% of the cluster
#                 25%    50%    75%   count    max      mean    min      std
# Danceability  0.549  0.621  0.688  6757.0  0.918  0.613705  0.117  0.10701
# The interquartile range (IQR) for Cluster 4 is 0.1389999999999999
# Variance is equal to 0.01145106872959323
# total number of outliers are 99 which is 1.47% of the cluster

# %%
anova("Danceability", 100)
# Out:
# F_onewayResult(statistic=62.8711490785012, pvalue=2.896397629450351e-33)
# ______________________________________________________________
# statistic = 74.82017650383571
# pvalue = 3.582169430915488e-33
# df = (3.0, 214.88105698088322)
# df_num = 3.0
# df_denom = 214.88105698088322
# nobs_t = 400.0
# n_groups = 4
# means = [0.77115 0.66427 0.77921 0.61291]
# nobs = [100. 100. 100. 100.]
# vars_ = [0.00723336 0.01987773 0.00490421 0.01041695]
# use_var = unequal
# welch_correction = True
# tuple = (74.82017650383571, 3.582169430915488e-33)
# ______________________________________________________________
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#   group1    group2  meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------
# Cluster 1 Cluster 2  -0.1069    0.0 -0.1445 -0.0693   True
# Cluster 1 Cluster 3   0.0081 0.9456 -0.0295  0.0456  False
# Cluster 1 Cluster 4  -0.1582    0.0 -0.1958 -0.1207   True
# Cluster 2 Cluster 3   0.1149    0.0  0.0774  0.1525   True
# Cluster 2 Cluster 4  -0.0514 0.0026 -0.0889 -0.0138   True
# Cluster 3 Cluster 4  -0.1663    0.0 -0.2039 -0.1287   True
# ----------------------------------------------------------

# %%
ratings("Danceability", 100)

# %% [markdown]
# ### Energy

# %%
plot(df, "Energy")

# %%
describe(df, "Energy")
# Out:
#           25%    50%    75%   count    max      mean     min       std
# Energy  0.364  0.437  0.499  6847.0  0.882  0.429426  0.0226  0.103209
# The interquartile range (IQR) for Cluster 1 is 0.135
# Variance is equal to 0.010652169671580933
# total number of outliers are 96 which is 1.4% of the cluster
#           25%    50%    75%   count    max     mean       min       std
# Energy  0.396  0.501  0.599  3081.0  0.961  0.49316  0.000177  0.154645
# The interquartile range (IQR) for Cluster 2 is 0.20299999999999996
# Variance is equal to 0.02391494249109663
# total number of outliers are 38 which is 1.23% of the cluster
#           25%    50%   75%   count    max      mean    min       std
# Energy  0.606  0.685  0.77  9691.0  0.997  0.690095  0.368  0.111688
# The interquartile range (IQR) for Cluster 3 is 0.16400000000000003
# Variance is equal to 0.012474280317965483
# total number of outliers are 0 which is 0.0% of the cluster
#           25%    50%    75%   count    max      mean    min       std
# Energy  0.627  0.714  0.802  6757.0  0.998  0.712764  0.215  0.120717
# The interquartile range (IQR) for Cluster 4 is 0.17500000000000004
# Variance is equal to 0.01457248817054664
# total number of outliers are 11 which is 0.16% of the cluster

# %%
anova("Energy", 100)
# Out:
# F_onewayResult(statistic=162.31397820966427, pvalue=1.3254042696421962e-68)
# ______________________________________________________________
# statistic = 184.58221555129043
# pvalue = 1.452711797848971e-59
# df = (3.0, 217.9676412127092)
# df_num = 3.0
# df_denom = 217.9676412127092
# nobs_t = 400.0
# n_groups = 4
# means = [0.40734  0.497801 0.69399  0.71414 ]
# nobs = [100. 100. 100. 100.]
# vars_ = [0.01172974 0.02101282 0.00898817 0.01375358]
# use_var = unequal
# welch_correction = True
# tuple = (184.58221555129043, 1.452711797848971e-59)
# ______________________________________________________________
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#   group1    group2  meandiff p-adj  lower  upper  reject
# --------------------------------------------------------
# Cluster 1 Cluster 2   0.0905   0.0  0.0475 0.1334   True
# Cluster 1 Cluster 3   0.2867   0.0  0.2437 0.3296   True
# Cluster 1 Cluster 4   0.3068   0.0  0.2638 0.3498   True
# Cluster 2 Cluster 3   0.1962   0.0  0.1532 0.2392   True
# Cluster 2 Cluster 4   0.2163   0.0  0.1734 0.2593   True
# Cluster 3 Cluster 4   0.0201 0.621 -0.0228 0.0631  False
# --------------------------------------------------------

# %%
ratings("Energy", 100)

# %% [markdown]
# ### Loudness

# %%
plot(df, "Loudness")

# %%
describe(df, "Loudness")
# Out:
#                25%       50%       75%   count       max      mean  min       std
# Loudness  0.619829  0.674375  0.726402  6847.0  0.857446  0.666632  0.0  0.082051
# The interquartile range (IQR) for Cluster 1 is 0.1065734735536551
# Variance is equal to 0.006732339404098371
# total number of outliers are 121 which is 1.77% of the cluster
#                25%       50%       75%   count       max      mean       min     std
# Loudness  0.687476  0.750859  0.805922  3081.0  0.954136  0.738565  0.158471  0.0937
# The interquartile range (IQR) for Cluster 2 is 0.11844655176868812
# Variance is equal to 0.008779721330602399
# total number of outliers are 64 which is 2.08% of the cluster
#                25%       50%       75%   count  max      mean       min       std
# Loudness  0.788843  0.827395  0.861631  9691.0  1.0  0.823598  0.610217  0.054394
# The interquartile range (IQR) for Cluster 3 is 0.07278881682643856
# Variance is equal to 0.0029587308528328735
# total number of outliers are 90 which is 0.93% of the cluster
#                25%       50%       75%   count       max      mean       min       std
# Loudness  0.795302  0.838325  0.873673  6757.0  0.999406  0.831622  0.528048  0.059954
# The interquartile range (IQR) for Cluster 4 is 0.07837006795690038
# Variance is equal to 0.0035945080106269066
# total number of outliers are 114 which is 1.69% of the cluster

# %%
anova("Loudness", 100)
# Out:
# F_onewayResult(statistic=104.8565044365386, pvalue=5.643869227224586e-50)
# ______________________________________________________________
# statistic = 114.27753402436808
# pvalue = 2.802928293223587e-44
# df = (3.0, 215.07624973073686)
# df_num = 3.0
# df_denom = 215.07624973073686
# nobs_t = 400.0
# n_groups = 4
# means = [0.66358828 0.73120384 0.82087104 0.82500478]
# nobs = [100. 100. 100. 100.]
# vars_ = [0.00662322 0.0101554  0.00321791 0.00296212]
# use_var = unequal
# welch_correction = True
# tuple = (114.27753402436808, 2.802928293223587e-44)
# ______________________________________________________________
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#   group1    group2  meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------
# Cluster 1 Cluster 2   0.0676    0.0    0.04 0.0953   True
# Cluster 1 Cluster 3   0.1573    0.0  0.1296 0.1849   True
# Cluster 1 Cluster 4   0.1614    0.0  0.1338 0.1891   True
# Cluster 2 Cluster 3   0.0897    0.0   0.062 0.1173   True
# Cluster 2 Cluster 4   0.0938    0.0  0.0662 0.1214   True
# Cluster 3 Cluster 4   0.0041 0.9805 -0.0235 0.0318  False
# ---------------------------------------------------------

# %%
ratings("Loudness", 100)

# %% [markdown]
# ### Speechiness

# %%
plot(df, "Speechiness")

# %%
describe(df, "Speechiness")
# Out:
#                  25%    50%    75%   count    max      mean     min       std
# Speechiness  0.06795  0.121  0.236  6847.0  0.959  0.166741  0.0251  0.128443
# The interquartile range (IQR) for Cluster 1 is 0.16804999999999998
# Variance is equal to 0.01649772840871772
# total number of outliers are 145 which is 2.12% of the cluster
#                 25%    50%    75%   count    max     mean     min       std
# Speechiness  0.0499  0.107  0.254  3081.0  0.957  0.17436  0.0246  0.170832
# The interquartile range (IQR) for Cluster 2 is 0.2041
# Variance is equal to 0.029183460406226686
# total number of outliers are 104 which is 3.38% of the cluster
#                 25%     50%    75%   count    max      mean     min       std
# Speechiness  0.0512  0.0852  0.171  9691.0  0.583  0.122118  0.0244  0.092105
# The interquartile range (IQR) for Cluster 3 is 0.11980000000000002
# Variance is equal to 0.008483367947634539
# total number of outliers are 252 which is 2.6% of the cluster
#                 25%    50%  75%   count   max      mean     min      std
# Speechiness  0.0755  0.191  0.3  6757.0  0.92  0.201914  0.0238  0.13377
# The interquartile range (IQR) for Cluster 4 is 0.22449999999999998
# Variance is equal to 0.017894471490407113
# total number of outliers are 26 which is 0.38% of the cluster

# %%
anova("Speechiness", 100)
# Out:
# F_onewayResult(statistic=3.349214024636622, pvalue=0.019128758198517278)
# ______________________________________________________________
# statistic = 3.4388420045454455
# pvalue = 0.01771584829670746
# df = (3.0, 217.48448784959893)
# df_num = 3.0
# df_denom = 217.48448784959893
# nobs_t = 400.0
# n_groups = 4
# means = [0.155052 0.159156 0.134952 0.192428]
# nobs = [100. 100. 100. 100.]
# vars_ = [0.01704039 0.01847028 0.01009056 0.02221735]
# use_var = unequal
# welch_correction = True
# tuple = (3.4388420045454455, 0.01771584829670746)
# ______________________________________________________________
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================
#   group1    group2  meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------
# Cluster 1 Cluster 2   0.0041 0.9961 -0.0434 0.0516  False
# Cluster 1 Cluster 3  -0.0201 0.6949 -0.0676 0.0274  False
# Cluster 1 Cluster 4   0.0374 0.1788 -0.0101 0.0849  False
# Cluster 2 Cluster 3  -0.0242 0.5543 -0.0717 0.0233  False
# Cluster 2 Cluster 4   0.0333 0.2716 -0.0142 0.0808  False
# Cluster 3 Cluster 4   0.0575 0.0104    0.01  0.105   True
# ---------------------------------------------------------

# %%
ratings("Speechiness", 100)

# %% [markdown]
# ### Liveness

# %%
plot(df, "Liveness")

# %%
describe(df, "Liveness")
# Out:
#              25%    50%    75%   count    max      mean     min       std
# Liveness  0.0729  0.103  0.163  6847.0  0.987  0.139256  0.0149  0.108534
# The interquartile range (IQR) for Cluster 1 is 0.0901
# Variance is equal to 0.011779706130086505
# total number of outliers are 684 which is 9.99% of the cluster
#             25%    50%    75%   count    max      mean     min       std
# Liveness  0.106  0.147  0.294  3081.0  0.993  0.229245  0.0242  0.194237
# The interquartile range (IQR) for Cluster 2 is 0.188
# Variance is equal to 0.037728043400169456
# total number of outliers are 255 which is 8.28% of the cluster
#             25%    50%    75%   count    max      mean     min       std
# Liveness  0.074  0.106  0.182  9691.0  0.736  0.142728  0.0139  0.098968
# The interquartile range (IQR) for Cluster 3 is 0.108
# Variance is equal to 0.00979467963526317
# total number of outliers are 461 which is 4.76% of the cluster
#             25%    50%    75%   count    max      mean    min       std
# Liveness  0.123  0.248  0.377  6757.0  0.999  0.305899  0.017  0.232057
# The interquartile range (IQR) for Cluster 4 is 0.254
# Variance is equal to 0.053850399861939555
# total number of outliers are 484 which is 7.16% of the cluster

# %%
anova("Liveness", 100)
# Out:
# F_onewayResult(statistic=25.701722793235962, pvalue=3.274879028188224e-15)
# ______________________________________________________________
# statistic = 23.888905568156066
# pvalue = 2.4430578241765463e-13
# df = (3.0, 209.5320924762406)
# df_num = 3.0
# df_denom = 209.5320924762406
# nobs_t = 400.0
# n_groups = 4
# means = [0.13289  0.236267 0.155326 0.318644]
# nobs = [100. 100. 100. 100.]
# vars_ = [0.00843758 0.04112266 0.01105342 0.0505396 ]
# use_var = unequal
# welch_correction = True
# tuple = (23.888905568156066, 2.4430578241765463e-13)
# ______________________________________________________________
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#   group1    group2  meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------
# Cluster 1 Cluster 2   0.1034 0.0001  0.0426  0.1642   True
# Cluster 1 Cluster 3   0.0224 0.7768 -0.0384  0.0833  False
# Cluster 1 Cluster 4   0.1858    0.0  0.1249  0.2466   True
# Cluster 2 Cluster 3  -0.0809 0.0037 -0.1418 -0.0201   True
# Cluster 2 Cluster 4   0.0824  0.003  0.0216  0.1432   True
# Cluster 3 Cluster 4   0.1633    0.0  0.1025  0.2241   True
# ----------------------------------------------------------

# %%
ratings("Liveness", 100)

# %% [markdown]
# ### Valence

# %%
plot(df, "Valence")

# %%
describe(df, "Valence")
# Out:
#            25%    50%    75%   count    max      mean     min       std
# Valence  0.565  0.703  0.832  6847.0  0.998  0.686128  0.0285  0.183034
# The interquartile range (IQR) for Cluster 1 is 0.267
# Variance is equal to 0.03350128693678546
# total number of outliers are 35 which is 0.51% of the cluster
#            25%    50%    75%   count    max      mean      min       std
# Valence  0.531  0.716  0.849  3081.0  0.986  0.673564  0.00001  0.218021
# The interquartile range (IQR) for Cluster 2 is 0.31799999999999995
# Variance is equal to 0.047533176056138375
# total number of outliers are 8 which is 0.26% of the cluster
#            25%   50%    75%   count    max      mean    min       std
# Valence  0.699  0.81  0.895  9691.0  0.997  0.787399  0.217  0.134889
# The interquartile range (IQR) for Cluster 3 is 0.19600000000000006
# Variance is equal to 0.018195106206550203
# total number of outliers are 81 which is 0.84% of the cluster
#            25%    50%   75%   count    max      mean     min       std
# Valence  0.431  0.577  0.71  6757.0  0.973  0.566478  0.0348  0.191448
# The interquartile range (IQR) for Cluster 4 is 0.27899999999999997
# Variance is equal to 0.03665239480496861
# total number of outliers are 0 which is 0.0% of the cluster

# %%
anova("Valence", 100)
# Out:
# F_onewayResult(statistic=27.879057798598122, pvalue=2.240449458888785e-16)
# ______________________________________________________________
# statistic = 35.269569814615714
# pvalue = 1.4112233438487607e-18
# df = (3.0, 214.9262243616731)
# df_num = 3.0
# df_denom = 214.9262243616731
# nobs_t = 400.0
# n_groups = 4
# means = [0.666887 0.676915 0.78385  0.54154 ]
# nobs = [100. 100. 100. 100.]
# vars_ = [0.03800297 0.04485348 0.01687332 0.04131803]
# use_var = unequal
# welch_correction = True
# tuple = (35.269569814615714, 1.4112233438487607e-18)
# ______________________________________________________________
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
#   group1    group2  meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------
# Cluster 1 Cluster 2     0.01 0.9816 -0.0585  0.0785  False
# Cluster 1 Cluster 3    0.117 0.0001  0.0484  0.1855   True
# Cluster 1 Cluster 4  -0.1253    0.0 -0.1939 -0.0568   True
# Cluster 2 Cluster 3   0.1069 0.0004  0.0384  0.1754   True
# Cluster 2 Cluster 4  -0.1354    0.0 -0.2039 -0.0669   True
# Cluster 3 Cluster 4  -0.2423    0.0 -0.3108 -0.1738   True
# ----------------------------------------------------------

# %%
ratings("Valence", 100)

# %% [markdown]
# ## Compare

# %% [markdown]
# - Danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# - Energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
#
# - Loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track. Values typical range between -60 and 0 db.
#
# - Speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
#
# - Acousticness: A measure from 0.0 to 1.0 of whether the track is acoustic.
#
# - Liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live.
#
# - Valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# #### High 0.7 - 0.9
# #### Moderate 0.4-0.69
# #### Low 0.0 - 0.39

# %%
compare(df, 100)

# %% [markdown]
# #### Cluster 1 Insights
#
# - High Danceability
# - Moderate Energy, Loudness and Valence
# - Low in Speechiness, Acousticness and Liveness
# __________________________________________________
# - 2nd in Danceability
# - 4th in Energy
# - 4th in Loudness
# - 3rd in Speechiness
# - 4th in Acousticness
# - 3rd in Liveness
# - 2nd in Valance (very close/similar to cluster 1)

# %% [markdown]
# #### Cluster 2 Insights
#
# - High in Loudness
# - Moderate in Danceability, Energy, Acousticness and Valance
# - Low in Speechiness and Liveness
# __________________________________________________
# - 3rd in Danceability (very close/similar to cluster 3)
# - 3rd in Energy
# - 1st in Loudness (very close/similar to cluster 3 & 4)
# - 2nd in Speechiness
# - 1st in Acousticness
# - 2nd in Liveness
# - 1st in Valance (very close/similar to cluster 1)

# %% [markdown]
# #### Cluster 3 Insights
#
# - High in Danceability, Loudness and Valance
# - Moderate Energy
# - Low in Speechiness, Aousticness and Liveness
# __________________________________________________
# - 1st in Danceability (very close/similar to cluster 1)
# - 2nd in Energy (very close/similar to cluster 4)
# - 1st in Loudness (very close/similar to cluster 2 & 4)
# - 4th in Speechiness
# - 3rd in Acousticness
# - 4th in Liveness
# - 1st in Valance

# %% [markdown]
# #### Cluster 4 Insights
#
# - High in Loudness
# - Moderate Danceability, Liveness and Valence
# - Low in Speechiness and Acousticness
# __________________________________________________
# - 4th in Danceability
# - 2nd in Energy
# - 2nd in Loudness (very close/similar to cluster 1)
# - 1st in Speechiness
# - 2nd in Acousticness
# - 1st in Liveness
# - 4th in Valance (very close/similar to cluster 1)

# %% [markdown]
# ## Recommenations vs Clusters

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Connect to the spotify API
client_id = "207d263141ce4bd489a6759df62d55fc"
client_secret = "3678f66a438f48108e0c47045aa13732"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
df2 = pd.read_csv('Files/tracks_classified.csv')

# %%
df2.head()
# Out:
#                 artist_id artist_name  track_name                track_id  popularity  explicit  danceability  energy  key  loudness  speechiness  acousticness  liveness  valence  tempo  time_signature  mode  release_year  duration  clusters
# 0  2O6ph9RDudyvAR4Gj6VDoE      $wizzz     L.I.F.E  0eyJ7wobiSnBiviFjDD4WV          13     False         0.618   0.557  0.0    -5.227       0.0747      0.482000     0.294    0.332  144.0             4.0   1.0          2021  2.703233         3
# 1  2O6ph9RDudyvAR4Gj6VDoE      $wizzz      G-spot  0n5HmWeoStEZzxdu4DFiBv          10     False         0.711   0.444  7.0    -7.602       0.2800      0.543000     0.118    0.630   80.0             4.0   0.0          2021  3.622750         1
# 2  2O6ph9RDudyvAR4Gj6VDoE      $wizzz  High grade  19BuQIrARlDVkOgY06BuP2          10     False         0.516   0.684  1.0    -5.736       0.0467      0.139000     0.113    0.135  100.0             4.0   0.0          2021  3.716350         3
# 3  2O6ph9RDudyvAR4Gj6VDoE      $wizzz       Story  4Fvl6HcI4kfiACcelfWhkw          10     False         0.491   0.467  0.0    -9.551       0.0545      0.154000     0.146    0.574  132.0             5.0   0.0          2021  3.245300         3
# 4  2O6ph9RDudyvAR4Gj6VDoE      $wizzz      Bubble  4VJMkS6IEdG7pN8UpJugvT          12     False         0.590   0.592  5.0    -7.909       0.2340      0.000575     0.405    0.293   70.0             3.0   0.0          2021  3.257150         3

# %%
df_artist = df2[['track_id','clusters']]

# %%
df_artist.head()
# Out:
#                  track_id  clusters
# 0  0eyJ7wobiSnBiviFjDD4WV         3
# 1  0n5HmWeoStEZzxdu4DFiBv         1
# 2  19BuQIrARlDVkOgY06BuP2         3
# 3  4Fvl6HcI4kfiACcelfWhkw         3
# 4  4VJMkS6IEdG7pN8UpJugvT         3

# %%
# Separate each cluster and take a somple from each
cluster_1 = df_artist[df_artist['clusters'] == 0].sample(frac=1, random_state=876).head()['track_id'].values.tolist()
cluster_2 = df_artist[df_artist['clusters'] == 1].sample(frac=1, random_state=876).head()['track_id'].values.tolist()
cluster_3 = df_artist[df_artist['clusters'] == 2].sample(frac=1, random_state=876).head()['track_id'].values.tolist()
cluster_4 = df_artist[df_artist['clusters'] == 3].sample(frac=1, random_state=876).head()['track_id'].values.tolist()

# %%
# Generate recommdations vased on each cluster using the spotify api
tracks_c1 = sp.recommendations(seed_tracks=cluster_1)['tracks']
tracks_c2 = sp.recommendations(seed_tracks=cluster_2)['tracks']
tracks_c3 = sp.recommendations(seed_tracks=cluster_3)['tracks']
tracks_c4 = sp.recommendations(seed_tracks=cluster_4)['tracks']

# %%
# Create dataframe for each recomendation
def recommendations(track_info):
    """
    Expects: The json file for tracks returned from spotiy api
    Return: Dataframe with all tracks and there features
    """ 
    recommendations = {"Artist":[], "Name":[], "Link":[], "Danceability":[], "Energy":[], "Speechiness":[], "Acousticness":[], "Liveness":[], "Valence":[]}
    sample_len = len(track_info)
    for i in range(sample_len):
        name = track_info[i]['name']
        link = track_info[i]['external_urls']['spotify']
        artist = track_info[i]["album"]["artists"][0]["name"]
        recommendations["Name"].append(name)
        recommendations["Link"].append(link)
        recommendations["Artist"].append(artist)
        track_id = track_info[i]["id"]
        track_features = sp.audio_features(track_id)[0]
        recommendations["Danceability"].append(track_features["danceability"])
        recommendations["Energy"].append(track_features["energy"])
        recommendations["Speechiness"].append(track_features["speechiness"])
        recommendations["Acousticness"].append(track_features["acousticness"])
        recommendations["Liveness"].append(track_features["liveness"])
        recommendations["Valence"].append(track_features["valence"])  
    return pd.DataFrame(recommendations)

# %%
# Compare recommendation sample with cluster sample
def compare2(df,df2, features):
    """
    Expects: Two dataframes that require comparison and the list of features
    Return: Bar graph comparing both samples and p-values for t-test comparisons
    """ 
    c1 = df[features].sample(20, random_state=876).mean()
    c2 = df2[features].mean()
    compare = pd.concat([
        pd.DataFrame(c1, columns=["Cluster"]),
        pd.DataFrame(c2, columns=["Recommendation"]),
    ], axis=1)
    # display(compare)
    
    fig, axs = plt.subplots(ncols=2, figsize=(20,8))
    plt.setp(axs, xlim=(0, 0.9))
    sns.barplot(data=compare[["Cluster"]], x="Cluster", y=compare.index, ax=axs[0]);
    sns.barplot(data=compare[["Recommendation"]], x="Recommendation", y=compare.index, ax=axs[1]);
    
    df_compare = compare.reset_index()
    df_compare2 = pd.pivot_table(df_compare, columns="index").reset_index()
    
    fig, axs2 = plt.subplots(ncols=6, figsize=(30,8))
    plt.setp(axs2, ylim=(0, 1))
    sns.barplot(data=df_compare2, y="Danceability", x="index", ax=axs2[0]);
    sns.barplot(data=df_compare2, y="Energy", x="index", ax=axs2[1]);
    sns.barplot(data=df_compare2, y="Speechiness", x="index", ax=axs2[2]);
    sns.barplot(data=df_compare2, y="Acousticness", x="index", ax=axs2[3]);
    sns.barplot(data=df_compare2, y="Liveness", x="index", ax=axs2[4]);
    sns.barplot(data=df_compare2, y="Valence", x="index", ax=axs2[5]);
    plt.show()
    
    # Run t-test to determine the differences
    for feature in features:
        result = stats.ttest_ind(df2[feature], df[feature].sample(100, random_state=876), equal_var=False)
        ci = 0.05
        if result[1] > ci:
            print(f"P-value = {result[1]} - similar {feature}")
        else:
            print(f"P-value = {result[1]} - dissimilar {feature}")

# %%
# Create databases for each recommendation
rec_c1 = recommendations(tracks_c1)
rec_c2 = recommendations(tracks_c2)
rec_c3 = recommendations(tracks_c3)
rec_c4 = recommendations(tracks_c4)

# %%
rec_c1.head()
# Out:
#                Artist                       Name                                               Link  Danceability  Energy  Speechiness  Acousticness  Liveness  Valence
# 0     Anthony Johnson          Sweet Inspiration  https://open.spotify.com/track/1QU9OfZclERh7T7...         0.806   0.367       0.0703        0.1050    0.0721    0.560
# 1  Niney The Observer                 Band Wagon  https://open.spotify.com/track/25PL0b4EHVysnZp...         0.928   0.394       0.0695        0.0307    0.3030    0.610
# 2      Derrick Morgan                Shake a Leg  https://open.spotify.com/track/3dOO9BLg4NKXDWg...         0.672   0.478       0.0437        0.7970    0.1450    0.908
# 3              Squash                    Surgery  https://open.spotify.com/track/3QJgUZ1giZG3Vhj...         0.441   0.513       0.3190        0.4690    0.0957    0.196
# 4     Various Artists  (Go) Find Yourself A Fool  https://open.spotify.com/track/2og48H8XIGi5crG...         0.578   0.454       0.0800        0.7010    0.2470    0.941

# %% [markdown]
# Loudness was excluded from the features because the nature of that feature is different from the normalized version used to create the clusters. It could be renormalized but it was originally normalized with whole database taken into consideration, and may be different if done on the isolated recommended sample.

# %%
features = ['Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Liveness', 'Valence']

# %%
compare2(cluster1, rec_c1, features)
# Out:
# P-value = 0.03581343873635532 - dissimilar Danceability
# P-value = 0.0029260953063327006 - dissimilar Energy
# P-value = 0.863783429409268 - similar Speechiness
# P-value = 0.04553034231274598 - dissimilar Acousticness
# P-value = 0.9001444104100056 - similar Liveness
# P-value = 0.641446365336789 - similar Valence

# %%
compare2(cluster2, rec_c2, features)
# Out:
# P-value = 0.04793465650974569 - dissimilar Danceability
# P-value = 0.0016160719395936164 - dissimilar Energy
# P-value = 0.07107811894792126 - similar Speechiness
# P-value = 1.3765090844026308e-09 - dissimilar Acousticness
# P-value = 0.033290865604752806 - dissimilar Liveness
# P-value = 0.034551993600423506 - dissimilar Valence

# %%
compare2(cluster3, rec_c3, features)
# Out:
# P-value = 0.6815958568258054 - similar Danceability
# P-value = 0.8261806200369957 - similar Energy
# P-value = 0.0733078947400058 - similar Speechiness
# P-value = 0.6522766164027486 - similar Acousticness
# P-value = 0.35130632526183914 - similar Liveness
# P-value = 0.49275994895753883 - similar Valence

# %%
compare2(cluster4, rec_c4, features)
# Out:
# P-value = 0.0007868423133141803 - dissimilar Danceability
# P-value = 0.06452795222876555 - similar Energy
# P-value = 0.6771458437859208 - similar Speechiness
# P-value = 0.028149501569530874 - dissimilar Acousticness
# P-value = 0.001278199095374706 - dissimilar Liveness
# P-value = 0.18122760520358408 - similar Valence

# %% [markdown]
# ### Report

# %% [markdown]
# Analyzing the differences between the clusters and recommendations, two things need to be taken into consideration.
# - The method spotify is using to make recommenations.
# - Are track features sufficient to make judgement on the genre of music.
#
# #### Spotify Recommendation
#
# Using my field knowledge about the characteristics for Jamaican music, I can conclude that the recommendations made by spotify are not uniform enough to make a conclusive judgment on the subgenre of Jamaican music. The songs recommended have a vast mixture of styles that qualify for all the subsets of Jamaican music.
# <br>
# <br>
# No that this has been established, how does spotify go about their recommendation? Spotify uses a complex and sophisticated stategy to recommend music. This inncludes the use of collaborative fillering and content based recommendation, combined with highly technical algorithms and natural language processing to make useful recommendations. So, the recommendation of music is not dependent on just the features of the tracks, it includes the actions of the user on the platform along with how people react to the track and the region they are from; just to name a few.
# <br>
# <br>
# So, are the track features sufficient to determine the subgenre among Jamaican music? Let's take a look at the results. Using K-means clustering, 4 clusters where established as the main categorization for Jamaican music. Comparing the 4 clusters using ANOVA, it was concluded that they share little similarities, but enough differences to keep them sparated. A sample of each cluster was taken and the Spotify API was used to generate recommendations based on each cluster. These recommendations were too diverse to make any conclusive judgnement about the subgenre by ear, so two sample t-tests were done to compare them to their respective clusters.
#
# ##### Cluster 1
# - Two sample T-test reveiled dissimilarities in only 1 feature (Energy), but visual analysis confirms 3 dissimilarites (Energy, Acousticness & Valence).
#
# ##### Cluster 2
# - Two sample T-test reveiled dissimilarities in 2 features (Speechiness & Acousticness), and visual analysis confirms the same, with massive dissimilarites in Acousticness.
#
# ##### Cluster 3
# - Two sample T-test and visual analysis reveiled dissimilarities in only 1 feature (Speechiness).
#
# ##### Cluster 4
# - Two sample T-test reveiled dissimilarities in 3 features (Danceability, Acousticness & Liveness), but visual analysis confirms dissimilarites in (Danceability, Acousticness, Liveness & Valence).
#
# <br>
#
# ### So the the use of spotify track features to determine the subgenres of Jamaician music was inconclusive.
